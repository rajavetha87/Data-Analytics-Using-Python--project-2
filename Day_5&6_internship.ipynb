# %% [markdown]
# <a href="https://colab.research.google.com/github/rajavetha87/Data-Analytics-Using-Python--project-2/blob/main/Day_5%266_internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.Series(
    [100,200,300],
    index=["ARUN","BABU","CHANDRU"]
)
print(data)
# Out:
# ARUN       100
# BABU       200
# CHANDRU    300
# dtype: int64

# %%
import pandas as pd
employee={
    "ID":[101,102,103],
    "NAME":["ARUN","BABU","CHANDRU"],
    "SALARY":[50000,60000,55000]
}
data=pd.DataFrame(employee)
print(data)
# Out:
#     ID     NAME  SALARY
# 0  101     ARUN   50000
# 1  102     BABU   60000
# 2  103  CHANDRU   55000

# %%
from google.colab import files
import pandas as pd
uploaded=files.upload()
df=pd.read_csv("products.csv")
print(df.head())
# Out:
#      <input type="file" id="files-5bdad3c9-3b19-4c93-9a98-67da5704517a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bdad3c9-3b19-4c93-9a98-67da5704517a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.head(2))
# Out:
#                              product_id  \
# 0  8826d916-cdfb-41c6-81ff-91a761565a70
# 1  2416da6e-c212-4ddb-8d88-00160eb686b2
#
#                                product_name  \
# 0  The Elite Cipher - PlayStation 5 Edition
# 1             KitchenAid Ultra-Soft Bedding
#
#                                  product_description        category  \
# 0  Bring joy to playtime with the The Elite Ciphe...    Toys & Games
# 1  Designed to make your home more beautiful and ...  Home & Kitchen
#
#    subcategory       brand  price  rating_avg  review_count  stock_quantity  \
# 0  Video Games      Hasbro  12.93         NaN             0              16
# 1      Bedding  KitchenAid  31.65         2.0             1              12
#
#    date_added
# 0  2024-09-04
# 1  2024-06-02

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1000 non-null   object
#  1   product_name         1000 non-null   object
#  2   product_description  1000 non-null   object
#  3   category             1000 non-null   object
#  4   subcategory          1000 non-null   object
#  5   brand                1000 non-null   object
#  6   price                1000 non-null   float64
#  7   rating_avg           452 non-null    float64
#  8   review_count         1000 non-null   int64
#  9   stock_quantity       1000 non-null   int64
#  10  date_added           1000 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 86.1+ KB
# None

# %%
print(df.tail())
# Out:
#                                product_id                     product_name  \
# 995  e9f96c73-5388-4116-b3e3-c0ab5e0e98ac     KitchenAid Furniture - Black
# 996  58fd8edb-60ef-4856-bf1f-644ffc133d12  Wilson Book19 Fitness Equipment
# 997  e672476a-04a1-4d79-aecc-25c1811df7c0      Adidas Pro15 Training Shoes
# 998  2598e723-19c8-4d48-acd3-ef82d5a1c555     Staples Office Furniture Pro
# 999  233d8a06-84c1-4fd8-a3b2-34bbce6e2385                    Sony Prime X8
#
#                                    product_description  \
# 995  Designed to make your home more beautiful and ...
# 996  Engineered for peak performance in any conditi...
# 997  Elevate your wardrobe with the Adidas Pro15 Tr...
# 998  Boost your productivity with the Staples Offic...
# 999  Upgrade your setup with the powerful Sony Prim...
#
#                    category        subcategory       brand   price  \
# 995          Home & Kitchen          Furniture  KitchenAid   19.59
# ...

# %%
data={
    'Name':['John','Mary','David','Sam'],
    'Sales':[1000,None,1500,None]
    }
df=pd.DataFrame(data)
print(df)
# Out:
#     Name   Sales
# 0   John  1000.0
# 1   Mary     NaN
# 2  David  1500.0
# 3    Sam     NaN

# %%
print(df.isnull())
# Out:
#     Name  Sales
# 0  False  False
# 1  False   True
# 2  False  False
# 3  False   True

# %%
clean_df=df.dropna()
print(clean_df)
# Out:
#     Name   Sales
# 0   John  1000.0
# 2  David  1500.0

# %%
df.fillna(0,inplace=True)
print(df)
# Out:
#     Name   Sales
# 0   John  1000.0
# 1   Mary     0.0
# 2  David  1500.0
# 3    Sam     0.0
